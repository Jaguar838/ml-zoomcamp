# %% [markdown]
# # Домашнє завдання №5: Розгортання моделей

# %%
# !wget https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Out:
# --2025-10-28 03:53:23--  https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin [following]
# --2025-10-28 03:53:23--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1300 (1.3K) [application/octet-stream]
# Saving to: ‘pipeline_v1.bin’
#
# pipeline_v1.bin     100%[===================>]   1.27K  --.-KB/s    in 0s
#
# 2025-10-28 03:53:24 (40.9 MB/s) - ‘pipeline_v1.bin’ saved [1300/1300]

# %% [markdown]
# ## Питання 1: MD5-сума для pipeline_v1.bin
#
# Давайте розрахуємо MD5-суму для завантаженого файлу конвеєра.

# %%
# !md5sum code/pipeline_v1.bin
# Out:
# md5sum: code/pipeline_v1.bin: No such file or directory

# %%
![[ "$(md5sum pipeline_v1.bin | awk '{print $1}')" == "7d17d2e4dfbaf1e408e1a62e6e880d49" ]] && echo "true" || echo "false"
# Out:
# true

# %% [markdown]
# ## Питання 2: Ймовірність конверсії
#
# Напишемо скрипт для завантаження моделі та розрахунку ймовірності конверсії для клієнта.

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.6.1
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.6.1
#   Using cached scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /home/yamhurov_oleh/machine-learning-zoomcamp/.venv/lib/python3.12/site-packages (from scikit-learn==1.6.1) (2.3.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/yamhurov_oleh/machine-learning-zoomcamp/.venv/lib/python3.12/site-packages (from scikit-learn==1.6.1) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/yamhurov_oleh/machine-learning-zoomcamp/.venv/lib/python3.12/site-packages (from scikit-learn==1.6.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/yamhurov_oleh/machine-learning-zoomcamp/.venv/lib/python3.12/site-packages (from scikit-learn==1.6.1) (3.6.0)
# Using cached scikit_learn-1.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.6.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import sklearn
sklearn.__version__
# Out:
# '1.6.1'

# %%
import pickle

# Шлях до файлу з моделлю
model_file = 'pipeline_v1.bin'

# 1. Завантаження моделі (конвеєра) з файлу
# 'rb' означає читання у бінарному режимі (read binary)
try:
    with open(model_file, 'rb') as f_in:
        pipeline = pickle.load(f_in)
    print(f"Модель '{model_file}' успішно завантажено.")
except FileNotFoundError:
    print(f"Помилка: Файл моделі '{model_file}' не знайдено.")
    print("Будь ласка, переконайтеся, що ви завантажили його за допомогою wget і він знаходиться в тій самій папці, що і скрипт.")
    exit()


# 2. Дані клієнта для оцінки
# Це ті самі дані, що вказані у домашньому завданні
client_record = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}

# 3. Отримання прогнозу
# Метод predict_proba повертає ймовірності для кожного класу [негативний, позитивний]
# Модель очікує на вхід список, тому ми передаємо [client_record]
prediction_probabilities = pipeline.predict_proba([client_record])[0]

# Ймовірність конверсії (позитивний клас, індекс 1)
conversion_probability = prediction_probabilities[1]

print(f"\nДані клієнта: {client_record}")
print(f"Ймовірність конверсії для цього клієнта: {conversion_probability:.3f}")
# Out:
# Модель 'pipeline_v1.bin' успішно завантажено.
#
# Дані клієнта: {'lead_source': 'paid_ads', 'number_of_courses_viewed': 2, 'annual_income': 79276.0}
# Ймовірність конверсії для цього клієнта: 0.534

# %% [markdown]
# ## Питання 3: Встановлення залежностей з `uv`
#
# Встановимо `uv` та використаємо його для додавання `fastapi`, `uvicorn` та `scikit-learn==1.6.1`.

# %%
# !pip install uv
# !uv --version
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting uv
#   Downloading uv-0.9.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.9.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 58.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: uv
# Successfully installed uv-0.9.6
# uv 0.7.18

# %%
# !uv init
# Out:
# Initialized project `05-deployment`

# %%
# !uv venv
# Out:
# Using CPython 3.12.3 interpreter at: /bin/python3.12
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate

# %%
# !uv add fastapi uvicorn scikit-learn==1.6.1
# Out:
# Resolved 21 packages in 385ms
# ⠙ Preparing packages... (0/19)
# ⠙ Preparing packages... (0/19)-------------     0 B/13.32 KiB
# ⠙ Preparing packages... (0/19)--------- 13.32 KiB/13.32 KiB
# ⠙ Preparing packages... (0/19)--------- 13.32 KiB/13.32 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# ⠙ Preparing packages... (0/19)-------------     0 B/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-extensions    ------------------------------     0 B/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-extensions    ------------------------------     0 B/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-extensions    ------------------------------     0 B/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-extensions    ------------------------------     0 B/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-inspection    ------------------------------     0 B/14.27 KiB
# typing-extensions    ------------------------------     0 B/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-inspection    ------------------------------     0 B/14.27 KiB
# typing-extensions    ------------------------------ 14.87 KiB/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-inspection    ------------------------------ 14.27 KiB/14.27 KiB
# typing-extensions    ------------------------------ 14.87 KiB/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-inspection    ------------------------------ 14.27 KiB/14.27 KiB
# typing-extensions    ------------------------------ 14.87 KiB/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-inspection    ------------------------------ 14.27 KiB/14.27 KiB
# typing-extensions    ------------------------------ 14.87 KiB/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-types      ------------------------------ 13.32 KiB/13.32 KiB
# typing-inspection    ------------------------------ 14.27 KiB/14.27 KiB
# typing-extensions    ------------------------------ 14.87 KiB/43.57 KiB
# ⠙ Preparing packages... (0/19)------------- 14.86 KiB/104.78 KiB
# annotated-doc        ------------------------------     0 B/5.36 KiB
# sniffio              ------------------------------ 10.00 KiB/10.00 KiB
# typing-inspection    ------------------------------ 14.27 KiB/14.27 KiB
# threadpoolctl        ------------------------------ 14.91 KiB/18.20 KiB
# h11                  ------------------------------     0 B/36.64 KiB
# typing-extensions    ------------------------------ 43.57 KiB/43.57 KiB
# uvicorn              ------------------------------ 14.85 KiB/66.51 KiB
# idna                 ------------------------------ 14.86 KiB/69.34 KiB
# starlette            ------------------------------ 14.88 KiB/72.44 KiB
# click                ------------------------------ 14.86 KiB/104.78 KiB
# fastapi              ------------------------------     0 B/105.84 KiB
# anyio                ------------------------------ 14.88 KiB/106.54 KiB
# joblib               ------------------------------ 14.89 KiB/301.17 KiB
# pydantic             ------------------------------ 14.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 14.91 KiB/1.97 MiB
# scikit-learn         ------------------------------     0 B/12.54 MiB
# numpy                ------------------------------     0 B/15.87 MiB
# ⠙ Preparing packages... (0/19)------------     0 B/34.02 MiB
# annotated-doc        ------------------------------ 5.36 KiB/5.36 KiB
# sniffio              ------------------------------ 10.00 KiB/10.00 KiB
# threadpoolctl        ------------------------------ 14.91 KiB/18.20 KiB
# h11                  ------------------------------ 14.89 KiB/36.64 KiB
# typing-extensions    ------------------------------ 43.57 KiB/43.57 KiB
# uvicorn              ------------------------------ 14.85 KiB/66.51 KiB
# idna                 ------------------------------ 30.86 KiB/69.34 KiB
# starlette            ------------------------------ 14.88 KiB/72.44 KiB
# click                ------------------------------ 66.66 KiB/104.78 KiB
# fastapi              ------------------------------ 14.85 KiB/105.84 KiB
# anyio                ------------------------------ 14.88 KiB/106.54 KiB
# joblib               ------------------------------ 14.89 KiB/301.17 KiB
# pydantic             ------------------------------ 14.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 14.91 KiB/1.97 MiB
# scikit-learn         ------------------------------ 14.91 KiB/12.54 MiB
# numpy                ------------------------------ 16.00 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 5.11 KiB/34.02 MiB
# annotated-doc        ------------------------------ 5.36 KiB/5.36 KiB
# sniffio              ------------------------------ 10.00 KiB/10.00 KiB
# threadpoolctl        ------------------------------ 14.91 KiB/18.20 KiB
# h11                  ------------------------------ 14.89 KiB/36.64 KiB
# typing-extensions    ------------------------------ 43.57 KiB/43.57 KiB
# uvicorn              ------------------------------ 14.85 KiB/66.51 KiB
# idna                 ------------------------------ 30.86 KiB/69.34 KiB
# starlette            ------------------------------ 14.88 KiB/72.44 KiB
# click                ------------------------------ 66.66 KiB/104.78 KiB
# fastapi              ------------------------------ 14.85 KiB/105.84 KiB
# anyio                ------------------------------ 46.88 KiB/106.54 KiB
# joblib               ------------------------------ 14.89 KiB/301.17 KiB
# pydantic             ------------------------------ 14.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 46.91 KiB/1.97 MiB
# scikit-learn         ------------------------------ 14.91 KiB/12.54 MiB
# numpy                ------------------------------ 16.00 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 17.70 KiB/34.02 MiB
# annotated-doc        ------------------------------ 5.36 KiB/5.36 KiB
# sniffio              ------------------------------ 10.00 KiB/10.00 KiB
# threadpoolctl        ------------------------------ 18.20 KiB/18.20 KiB
# h11                  ------------------------------ 14.89 KiB/36.64 KiB
# uvicorn              ------------------------------ 14.85 KiB/66.51 KiB
# idna                 ------------------------------ 30.86 KiB/69.34 KiB
# starlette            ------------------------------ 14.88 KiB/72.44 KiB
# click                ------------------------------ 66.66 KiB/104.78 KiB
# fastapi              ------------------------------ 14.85 KiB/105.84 KiB
# anyio                ------------------------------ 46.88 KiB/106.54 KiB
# joblib               ------------------------------ 30.89 KiB/301.17 KiB
# pydantic             ------------------------------ 14.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 46.91 KiB/1.97 MiB
# scikit-learn         ------------------------------ 14.91 KiB/12.54 MiB
# numpy                ------------------------------ 16.00 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 17.70 KiB/34.02 MiB
# annotated-doc        ------------------------------ 5.36 KiB/5.36 KiB
# sniffio              ------------------------------ 10.00 KiB/10.00 KiB
# h11                  ------------------------------ 30.89 KiB/36.64 KiB
# uvicorn              ------------------------------ 14.85 KiB/66.51 KiB
# idna                 ------------------------------ 69.34 KiB/69.34 KiB
# starlette            ------------------------------ 14.88 KiB/72.44 KiB
# click                ------------------------------ 66.66 KiB/104.78 KiB
# fastapi              ------------------------------ 14.85 KiB/105.84 KiB
# anyio                ------------------------------ 46.88 KiB/106.54 KiB
# joblib               ------------------------------ 30.89 KiB/301.17 KiB
# pydantic             ------------------------------ 30.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 286.81 KiB/1.97 MiB
# scikit-learn         ------------------------------ 14.91 KiB/12.54 MiB
# numpy                ------------------------------ 76.24 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 96.00 KiB/34.02 MiB
# sniffio              ------------------------------ 10.00 KiB/10.00 KiB
# h11                  ------------------------------ 30.89 KiB/36.64 KiB
# uvicorn              ------------------------------ 30.85 KiB/66.51 KiB
# idna                 ------------------------------ 69.34 KiB/69.34 KiB
# starlette            ------------------------------ 30.88 KiB/72.44 KiB
# click                ------------------------------ 78.86 KiB/104.78 KiB
# fastapi              ------------------------------ 14.85 KiB/105.84 KiB
# anyio                ------------------------------ 62.88 KiB/106.54 KiB
# joblib               ------------------------------ 30.89 KiB/301.17 KiB
# pydantic             ------------------------------ 46.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1022.81 KiB/1.97 MiB
# scikit-learn         ------------------------------ 14.91 KiB/12.54 MiB
# numpy                ------------------------------ 76.24 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 96.00 KiB/34.02 MiB
# sniffio              ------------------------------ 10.00 KiB/10.00 KiB
# h11                  ------------------------------ 30.89 KiB/36.64 KiB
# uvicorn              ------------------------------ 30.85 KiB/66.51 KiB
# starlette            ------------------------------ 30.88 KiB/72.44 KiB
# click                ------------------------------ 94.86 KiB/104.78 KiB
# fastapi              ------------------------------ 14.85 KiB/105.84 KiB
# anyio                ------------------------------ 62.88 KiB/106.54 KiB
# joblib               ------------------------------ 30.89 KiB/301.17 KiB
# pydantic             ------------------------------ 62.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1022.81 KiB/1.97 MiB
# scikit-learn         ------------------------------ 14.91 KiB/12.54 MiB
# numpy                ------------------------------ 76.24 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 113.75 KiB/34.02 MiB
# sniffio              ------------------------------ 10.00 KiB/10.00 KiB
# h11                  ------------------------------ 30.89 KiB/36.64 KiB
# uvicorn              ------------------------------ 30.85 KiB/66.51 KiB
# starlette            ------------------------------ 62.88 KiB/72.44 KiB
# click                ------------------------------ 104.78 KiB/104.78 KiB
# fastapi              ------------------------------ 30.85 KiB/105.84 KiB
# anyio                ------------------------------ 62.88 KiB/106.54 KiB
# joblib               ------------------------------ 46.89 KiB/301.17 KiB
# pydantic             ------------------------------ 62.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.43 MiB/1.97 MiB
# scikit-learn         ------------------------------ 14.91 KiB/12.54 MiB
# numpy                ------------------------------ 76.24 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 144.00 KiB/34.02 MiB
# h11                  ------------------------------ 30.89 KiB/36.64 KiB
# uvicorn              ------------------------------ 30.85 KiB/66.51 KiB
# starlette            ------------------------------ 62.88 KiB/72.44 KiB
# click                ------------------------------ 104.78 KiB/104.78 KiB
# fastapi              ------------------------------ 30.85 KiB/105.84 KiB
# anyio                ------------------------------ 62.88 KiB/106.54 KiB
# joblib               ------------------------------ 46.89 KiB/301.17 KiB
# pydantic             ------------------------------ 62.88 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.43 MiB/1.97 MiB
# scikit-learn         ------------------------------ 14.91 KiB/12.54 MiB
# numpy                ------------------------------ 76.24 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 160.00 KiB/34.02 MiB
# uvicorn              ------------------------------ 30.85 KiB/66.51 KiB
# starlette            ------------------------------ 62.88 KiB/72.44 KiB
# click                ------------------------------ 104.78 KiB/104.78 KiB
# fastapi              ------------------------------ 46.75 KiB/105.84 KiB
# anyio                ------------------------------ 78.88 KiB/106.54 KiB
# joblib               ------------------------------ 78.83 KiB/301.17 KiB
# pydantic             ------------------------------ 136.58 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.59 MiB/1.97 MiB
# scikit-learn         ------------------------------ 126.91 KiB/12.54 MiB
# numpy                ------------------------------ 76.24 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 161.52 KiB/34.02 MiB
# uvicorn              ------------------------------ 30.85 KiB/66.51 KiB
# starlette            ------------------------------ 62.88 KiB/72.44 KiB
# fastapi              ------------------------------ 46.75 KiB/105.84 KiB
# anyio                ------------------------------ 78.88 KiB/106.54 KiB
# joblib               ------------------------------ 78.83 KiB/301.17 KiB
# pydantic             ------------------------------ 136.58 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.59 MiB/1.97 MiB
# scikit-learn         ------------------------------ 126.91 KiB/12.54 MiB
# numpy                ------------------------------ 76.24 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------ 177.52 KiB/34.02 MiB
# uvicorn              ------------------------------ 46.85 KiB/66.51 KiB
# fastapi              ------------------------------ 62.75 KiB/105.84 KiB
# anyio                ------------------------------ 106.54 KiB/106.54 KiB
# joblib               ------------------------------ 126.83 KiB/301.17 KiB
# pydantic             ------------------------------ 171.60 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.73 MiB/1.97 MiB
# scikit-learn         ------------------------------ 206.80 KiB/12.54 MiB
# numpy                ------------------------------ 141.88 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------- 256.00 KiB/34.02 MiB
# uvicorn              ------------------------------ 62.85 KiB/66.51 KiB
# fastapi              ------------------------------ 62.75 KiB/105.84 KiB
# anyio                ------------------------------ 106.54 KiB/106.54 KiB
# joblib               ------------------------------ 142.83 KiB/301.17 KiB
# pydantic             ------------------------------ 187.60 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.84 MiB/1.97 MiB
# scikit-learn         ------------------------------ 238.91 KiB/12.54 MiB
# numpy                ------------------------------ 157.88 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------- 320.00 KiB/34.02 MiB
# fastapi              ------------------------------ 62.75 KiB/105.84 KiB
# anyio                ------------------------------ 106.54 KiB/106.54 KiB
# joblib               ------------------------------ 142.83 KiB/301.17 KiB
# pydantic             ------------------------------ 203.60 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.84 MiB/1.97 MiB
# scikit-learn         ------------------------------ 238.91 KiB/12.54 MiB
# numpy                ------------------------------ 157.88 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------- 320.00 KiB/34.02 MiB
# fastapi              ------------------------------ 94.85 KiB/105.84 KiB
# joblib               ------------------------------ 158.83 KiB/301.17 KiB
# pydantic             ------------------------------ 236.89 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.86 MiB/1.97 MiB
# scikit-learn         ------------------------------ 270.91 KiB/12.54 MiB
# numpy                ------------------------------ 173.88 KiB/15.87 MiB
# ⠙ Preparing packages... (0/19)------------- 336.00 KiB/34.02 MiB
# fastapi              ------------------------------ 94.85 KiB/105.84 KiB
# joblib               ------------------------------ 174.83 KiB/301.17 KiB
# pydantic             ------------------------------ 252.79 KiB/451.59 KiB
# pydantic-core        ------------------------------ 1.92 MiB/1.97 MiB
# scikit-learn         ------------------------------ 472.56 KiB/12.54 MiB
# numpy                ------------------------------ 1.65 MiB/15.87 MiB
# ⠹ Preparing packages... (12/19)------------ 352.00 KiB/34.02 MiB
# fastapi              ------------------------------ 94.85 KiB/105.84 KiB
# joblib               ------------------------------ 174.83 KiB/301.17 KiB
# pydantic             ------------------------------ 267.60 KiB/451.59 KiB
# scikit-learn         ------------------------------ 536.56 KiB/12.54 MiB
# numpy                ------------------------------ 3.40 MiB/15.87 MiB
# ⠹ Preparing packages... (12/19)------------ 352.00 KiB/34.02 MiB
# joblib               ------------------------------ 190.83 KiB/301.17 KiB
# pydantic             ------------------------------ 287.60 KiB/451.59 KiB
# scikit-learn         ------------------------------ 712.46 KiB/12.54 MiB
# numpy                ------------------------------ 3.86 MiB/15.87 MiB
# ⠹ Preparing packages... (12/19)------------ 352.00 KiB/34.02 MiB
# joblib               ------------------------------ 206.83 KiB/301.17 KiB
# pydantic             ------------------------------ 287.60 KiB/451.59 KiB
# scikit-learn         ------------------------------ 728.56 KiB/12.54 MiB
# numpy                ------------------------------ 3.89 MiB/15.87 MiB
# ⠹ Preparing packages... (12/19)------------ 366.28 KiB/34.02 MiB
# joblib               ------------------------------ 270.83 KiB/301.17 KiB
# pydantic             ------------------------------ 451.59 KiB/451.59 KiB
# scikit-learn         ------------------------------ 1.31 MiB/12.54 MiB
# numpy                ------------------------------ 4.09 MiB/15.87 MiB
# ⠹ Preparing packages... (12/19)------------ 464.00 KiB/34.02 MiB
# joblib               ------------------------------ 270.83 KiB/301.17 KiB
# scikit-learn         ------------------------------ 1.31 MiB/12.54 MiB
# numpy                ------------------------------ 4.09 MiB/15.87 MiB
# ⠹ Preparing packages... (12/19)------------ 464.00 KiB/34.02 MiB
# scikit-learn         ------------------------------ 1.90 MiB/12.54 MiB
# numpy                ------------------------------ 4.14 MiB/15.87 MiB
# ⠹ Preparing packages... (12/19)------------ 528.00 KiB/34.02 MiB
# scikit-learn         ------------------------------ 2.42 MiB/12.54 MiB
# numpy                ------------------------------ 4.25 MiB/15.87 MiB
# ⠹ Preparing packages... (12/19)------------ 875.00 KiB/34.02 MiB
# scikit-learn         ------------------------------ 3.24 MiB/12.54 MiB
# numpy                ------------------------------ 4.80 MiB/15.87 MiB
# ⠸ Preparing packages... (16/19)------------ 1.75 MiB/34.02 MiB
# scikit-learn         ------------------------------ 3.33 MiB/12.54 MiB
# numpy                ------------------------------ 5.04 MiB/15.87 MiB
# ⠸ Preparing packages... (16/19)------------ 2.88 MiB/34.02 MiB
# scikit-learn         ------------------------------ 3.86 MiB/12.54 MiB
# numpy                ------------------------------ 5.17 MiB/15.87 MiB
# ⠸ Preparing packages... (16/19)------------ 4.05 MiB/34.02 MiB
# scikit-learn         ------------------------------ 4.93 MiB/12.54 MiB
# numpy                ------------------------------ 5.23 MiB/15.87 MiB
# ⠸ Preparing packages... (16/19)------------ 4.38 MiB/34.02 MiB
# scikit-learn         ------------------------------ 6.59 MiB/12.54 MiB
# numpy                ------------------------------ 5.44 MiB/15.87 MiB
# ⠼ Preparing packages... (16/19)------------ 4.39 MiB/34.02 MiB
# scikit-learn         ------------------------------ 7.64 MiB/12.54 MiB
# numpy                ------------------------------ 5.89 MiB/15.87 MiB
# ⠼ Preparing packages... (16/19)------------ 4.47 MiB/34.02 MiB
# scikit-learn         ------------------------------ 7.99 MiB/12.54 MiB
# numpy                ------------------------------ 6.01 MiB/15.87 MiB
# ⠼ Preparing packages... (16/19)------------ 5.80 MiB/34.02 MiB
# scikit-learn         ------------------------------ 8.44 MiB/12.54 MiB
# numpy                ------------------------------ 6.20 MiB/15.87 MiB
# ⠼ Preparing packages... (16/19)------------ 6.39 MiB/34.02 MiB
# scikit-learn         ------------------------------ 9.35 MiB/12.54 MiB
# numpy                ------------------------------ 7.01 MiB/15.87 MiB
# ⠴ Preparing packages... (16/19)------------ 6.72 MiB/34.02 MiB
# scikit-learn         ------------------------------ 9.80 MiB/12.54 MiB
# numpy                ------------------------------ 7.67 MiB/15.87 MiB
# ⠴ Preparing packages... (16/19)------------ 7.47 MiB/34.02 MiB
# scikit-learn         ------------------------------ 10.31 MiB/12.54 MiB
# numpy                ------------------------------ 7.70 MiB/15.87 MiB
# ⠴ Preparing packages... (16/19)------------ 9.54 MiB/34.02 MiB
# scikit-learn         ------------------------------ 11.33 MiB/12.54 MiB
# numpy                ------------------------------ 7.73 MiB/15.87 MiB
# ⠴ Preparing packages... (16/19)------------ 10.59 MiB/34.02 MiB
# scikit-learn         ------------------------------ 12.44 MiB/12.54 MiB
# numpy                ------------------------------ 7.80 MiB/15.87 MiB
# ⠦ Preparing packages... (16/19)------------ 10.94 MiB/34.02 MiB
# scikit-learn         ------------------------------ 12.44 MiB/12.54 MiB
# numpy                ------------------------------ 11.89 MiB/15.87 MiB
# ⠦ Preparing packages... (16/19)------------ 11.09 MiB/34.02 MiB
# scikit-learn         ------------------------------ 12.52 MiB/12.54 MiB
# numpy                ------------------------------ 15.83 MiB/15.87 MiB
# ⠦ Preparing packages... (16/19)------------ 11.31 MiB/34.02 MiB
# scikit-learn         ------------------------------ 12.52 MiB/12.54 MiB
# ⠦ Preparing packages... (16/19)------------ 11.33 MiB/34.02 MiB
# ⠦ Preparing packages... (16/19)------------ 11.52 MiB/34.02 MiB
# ⠦ Preparing packages... (16/19)------------ 13.49 MiB/34.02 MiB
# ⠧ Preparing packages... (18/19)------------ 14.83 MiB/34.02 MiB
# ⠧ Preparing packages... (18/19)------------ 16.86 MiB/34.02 MiB
# ⠧ Preparing packages... (18/19)------------ 19.93 MiB/34.02 MiB
# ⠧ Preparing packages... (18/19)2m---------- 22.30 MiB/34.02 MiB
# ⠇ Preparing packages... (18/19)-------- 24.57 MiB/34.02 MiB
# ⠇ Preparing packages... (18/19)-------- 27.08 MiB/34.02 MiB
# ⠇ Preparing packages... (18/19)-------- 30.68 MiB/34.02 MiB
# Prepared 19 packages in 1.55s
# Installed 19 packages in 80ms
#  + annotated-doc==0.0.3
#  + annotated-types==0.7.0
#  + anyio==4.11.0
#  + click==8.3.0
#  + fastapi==0.120.2
#  + h11==0.16.0
#  + idna==3.11
#  + joblib==1.5.2
#  + numpy==2.3.4
#  + pydantic==2.12.3
#  + pydantic-core==2.41.4
#  + scikit-learn==1.6.1
#  + scipy==1.16.3
#  + sniffio==1.3.1
#  + starlette==0.49.1
#  + threadpoolctl==3.6.0
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + uvicorn==0.38.0

# %% [markdown]
# ## Питання 4: Ймовірність конверсії (через веб-сервіс)
#
# Тепер давайте запитаємо наш локальний веб-сервіс, щоб отримати прогноз для іншого клієнта.

# %%
import requests

# URL вашого FastAPI сервісу
# Якщо ви запускаєте його локально, це буде http://localhost:8000
url = "http://localhost:8000/predict"

# Дані клієнта для оцінки, як зазначено в завданні
client = {
    "lead_source": "organic_search",
    "number_of_courses_viewed": 4,
    "annual_income": 80304.0
}

# Надсилаємо POST-запит до сервісу
response = requests.post(url, json=client).json()

# Виводимо отриману ймовірність
print(f"Ймовірність конверсії для цього клієнта: {response['conversion_probability']:.3f}")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /usr/local/lib/python3.12/dist-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/connection.py:494, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     493     self.putheader(header, value)
# --> 494 self.endheaders()
#     496 # If we're given a body we start sending that in chunks.
#
# File /usr/lib/python3.12/http/client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.12/http/client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File /usr/lib/python3.12/http/client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/connection.py:325, in HTTPConnection.connect(self)
#     324 def connect(self) -> None:
# --> 325     self.sock = self._new_conn()
#     326     if self._tunnel_host:
#     327         # If we're tunneling it means we're connected to our proxy.
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f888227a4b0>: Failed to establish a new connection: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File /usr/local/lib/python3.12/dist-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=8000): Max retries exceeded with url: /predict (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f888227a4b0>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[12], line 15
#       8 client = {
#       9     "lead_source": "organic_search",
#      10     "number_of_courses_viewed": 4,
#      11     "annual_income": 80304.0
#      12 }
#      14 # Надсилаємо POST-запит до сервісу
# ---> 15 response = requests.post(url, json=client).json()
#      17 # Виводимо отриману ймовірність
#      18 print(f"Ймовірність конверсії для цього клієнта: {response['conversion_probability']:.3f}")
#
# File /usr/local/lib/python3.12/dist-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.12/dist-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.12/dist-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=8000): Max retries exceeded with url: /predict (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f888227a4b0>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %% [markdown]
# ## Питання 5: Розмір Docker-образу
#
# Завантажимо базовий образ Docker і перевіримо його розмір.

# %%
# !docker pull agrigorev/zoomcamp-model:2025
# Out:
# 2025: Pulling from agrigorev/zoomcamp-model
#
# 2667830b: Pulling fs layer
# 1082f6f0: Pulling fs layer
# f5177ae2: Pulling fs layer
# 357cf7a1: Pulling fs layer
# 2b9cc6ee: Pulling fs layer
# Digest: sha256:14d79fde0bbf078eb18c99c2bd007205917b758ec11060b2994963a1e485c2ae[6A
# Status: Downloaded newer image for agrigorev/zoomcamp-model:2025
# docker.io/agrigorev/zoomcamp-model:2025

# %%
# !docker images
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED      SIZE
# agrigorev/zoomcamp-model   2025      4a9ecc576ae9   9 days ago   121MB

# %% [markdown]
# ## Питання 6: Ймовірність конверсії (через Docker)
#
# Після запуску контейнера Docker з нашим додатком, ми можемо знову надіслати запит для отримання прогнозу.

# %%
# !docker build -t ml-zoomcamp-hw05 .
# !docker run -it --rm -p 8000:8000 ml-zoomcamp-hw05
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  0.2s
# [+] Building 0.3s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  0.3s
# [+] Building 0.5s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  0.5s
# [+] Building 0.6s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  0.6s
# [+] Building 0.8s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  0.8s
# [+] Building 0.9s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  0.9s
# [+] Building 1.1s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  1.1s
# [+] Building 1.2s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  1.2s
# [+] Building 1.4s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  1.4s
# [+] Building 1.5s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  1.5s
# [+] Building 1.7s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  1.7s
# [+] Building 1.8s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  1.8s
# [+] Building 1.9s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  1.9s
#  => => # Collecting fastapi
# [+] Building 2.0s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  2.0s
#  => => # Collecting fastapi
#  => => #   Downloading fastapi-0.120.2-py3-none-any.whl.metadata (28 kB)
#  => => # Collecting uvicorn
#  => => #   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# [+] Building 2.1s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  2.1s
#  => => # Collecting fastapi
#  => => #   Downloading fastapi-0.120.2-py3-none-any.whl.metadata (28 kB)
#  => => # Collecting uvicorn
#  => => #   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
#  => => # Collecting scikit-learn==1.6.1
# [+] Building 2.3s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  2.3s
#  => => #   Downloading fastapi-0.120.2-py3-none-any.whl.metadata (28 kB)
#  => => # Collecting uvicorn
#  => => #   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
#  => => # Collecting scikit-learn==1.6.1
#  => => #   Downloading scikit_learn-1.6.1-cp313-cp313-manylinux_2_17_x86_64.man
#  => => # ylinux2014_x86_64.whl.metadata (18 kB)
# [+] Building 2.4s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  2.3s
#  => => # Collecting uvicorn
#  => => #   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
#  => => # Collecting scikit-learn==1.6.1
#  => => #   Downloading scikit_learn-1.6.1-cp313-cp313-manylinux_2_17_x86_64.man
#  => => # ylinux2014_x86_64.whl.metadata (18 kB)
#  => => # Collecting numpy>=1.19.5 (from scikit-learn==1.6.1)
# [+] Building 2.5s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  2.5s
#  => => #   Downloading scikit_learn-1.6.1-cp313-cp313-manylinux_2_17_x86_64.man
#  => => # ylinux2014_x86_64.whl.metadata (18 kB)
#  => => # Collecting numpy>=1.19.5 (from scikit-learn==1.6.1)
#  => => #   Downloading numpy-2.3.4-cp313-cp313-manylinux_2_27_x86_64.manylinux_
#  => => # 2_28_x86_64.whl.metadata (62 kB)
#  => => # Collecting scipy>=1.6.0 (from scikit-learn==1.6.1)
# [+] Building 2.6s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  2.6s
#  => => # 2_17_x86_64.whl.metadata (62 kB)
#  => => # Collecting joblib>=1.2.0 (from scikit-learn==1.6.1)
#  => => #   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
#  => => # Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.6.1)
#  => => #   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
#  => => # Collecting starlette<0.50.0,>=0.40.0 (from fastapi)
# [+] Building 2.8s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  2.8s
#  => => # Collecting joblib>=1.2.0 (from scikit-learn==1.6.1)
#  => => #   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
#  => => # Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.6.1)
#  => => #   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
#  => => # Collecting starlette<0.50.0,>=0.40.0 (from fastapi)
#  => => #   Downloading starlette-0.49.1-py3-none-any.whl.metadata (6.4 kB)
# [+] Building 2.8s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  2.8s
#  => => # Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.6.1)
#  => => #   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
#  => => # Collecting starlette<0.50.0,>=0.40.0 (from fastapi)
#  => => #   Downloading starlette-0.49.1-py3-none-any.whl.metadata (6.4 kB)
#  => => # Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.
#  => => # 4 (from fastapi)
# [+] Building 3.0s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  3.0s
#  => => # kB)
#  => => # Collecting annotated-doc>=0.0.2 (from fastapi)
#  => => #   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
#  => => # Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,
#  => => # !=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#  => => #   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# [+] Building 3.2s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  3.2s
#  => => # kB)
#  => => # Collecting annotated-doc>=0.0.2 (from fastapi)
#  => => #   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
#  => => # Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,
#  => => # !=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#  => => #   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# [+] Building 3.3s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  3.3s
#  => => # kB)
#  => => # Collecting annotated-doc>=0.0.2 (from fastapi)
#  => => #   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
#  => => # Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,
#  => => # !=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#  => => #   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# [+] Building 3.5s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  3.5s
#  => => # kB)
#  => => # Collecting annotated-doc>=0.0.2 (from fastapi)
#  => => #   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
#  => => # Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,
#  => => # !=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#  => => #   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# [+] Building 3.6s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  3.6s
#  => => #   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
#  => => # Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,
#  => => # !=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#  => => #   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
#  => => # Collecting pydantic-core==2.41.4 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!
#  => => # =2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
# [+] Building 3.7s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  3.7s
#  => => #   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
#  => => # Collecting idna>=2.8 (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0-
#  => => # >fastapi)
#  => => #   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
#  => => # Collecting sniffio>=1.1 (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40
#  => => # .0->fastapi)
# [+] Building 3.9s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  3.9s
#  => => # Collecting h11>=0.8 (from uvicorn)
#  => => #   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
#  => => # Downloading scikit_learn-1.6.1-cp313-cp313-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl (13.2 MB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 157.5 MB/s et
#  => => # a 0:00:00
# [+] Building 4.0s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  4.0s
#  => => # Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#  => => # Downloading annotated_doc-0.0.3-py3-none-any.whl (5.5 kB)
#  => => # Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
#  => => # Downloading click-8.3.0-py3-none-any.whl (107 kB)
#  => => # Downloading h11-0.16.0-py3-none-any.whl (37 kB)
#  => => # Downloading idna-3.11-py3-none-any.whl (71 kB)
# [+] Building 4.2s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  4.1s
#  => => # Downloading idna-3.11-py3-none-any.whl (71 kB)
#  => => # Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#  => => # Downloading numpy-2.3.4-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_
#  => => # 28_x86_64.whl (16.6 MB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 133.0 MB/s et
#  => => # a 0:00:00
# [+] Building 4.3s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  4.3s
#  => => # Downloading numpy-2.3.4-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_
#  => => # 28_x86_64.whl (16.6 MB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 133.0 MB/s et
#  => => # a 0:00:00
#  => => # Downloading scipy-1.16.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_
#  => => # 17_x86_64.whl (35.7 MB)
# [+] Building 4.4s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  4.4s
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 133.0 MB/s et
#  => => # a 0:00:00
#  => => # Downloading scipy-1.16.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_
#  => => # 17_x86_64.whl (35.7 MB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 159.8 MB/s et
#  => => # a 0:00:00
# [+] Building 4.6s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  4.5s
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 159.8 MB/s et
#  => => # a 0:00:00
#  => => # Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
#  => => # Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
#  => => # Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#  => => # Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# [+] Building 4.6s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  4.6s
#  => => # Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#  => => # Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
#  => => # Installing collected packages: typing-extensions, threadpoolctl, sniff
#  => => # io, numpy, joblib, idna, h11, click, annotated-types, annotated-doc, u
#  => => # vicorn, typing-inspection, scipy, pydantic-core, anyio, starlette, sci
#  => => # kit-learn, pydantic, fastapi
# [+] Building 4.7s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  4.7s
#  => => # Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#  => => # Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
#  => => # Installing collected packages: typing-extensions, threadpoolctl, sniff
#  => => # io, numpy, joblib, idna, h11, click, annotated-types, annotated-doc, u
#  => => # vicorn, typing-inspection, scipy, pydantic-core, anyio, starlette, sci
#  => => # kit-learn, pydantic, fastapi
# [+] Building 4.9s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  4.9s
#  => => # Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#  => => # Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
#  => => # Installing collected packages: typing-extensions, threadpoolctl, sniff
#  => => # io, numpy, joblib, idna, h11, click, annotated-types, annotated-doc, u
#  => => # vicorn, typing-inspection, scipy, pydantic-core, anyio, starlette, sci
#  => => # kit-learn, pydantic, fastapi
# [+] Building 5.0s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  5.0s
#  => => # Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#  => => # Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
#  => => # Installing collected packages: typing-extensions, threadpoolctl, sniff
#  => => # io, numpy, joblib, idna, h11, click, annotated-types, annotated-doc, u
#  => => # vicorn, typing-inspection, scipy, pydantic-core, anyio, starlette, sci
#  => => # kit-learn, pydantic, fastapi
# [+] Building 5.2s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  5.2s
#  => => # Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#  => => # Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
#  => => # Installing collected packages: typing-extensions, threadpoolctl, sniff
#  => => # io, numpy, joblib, idna, h11, click, annotated-types, annotated-doc, u
#  => => # vicorn, typing-inspection, scipy, pydantic-core, anyio, starlette, sci
#  => => # kit-learn, pydantic, fastapi
# [+] Building 5.3s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  5.3s
#  => => # Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#  => => # Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
#  => => # Installing collected packages: typing-extensions, threadpoolctl, sniff
#  => => # io, numpy, joblib, idna, h11, click, annotated-types, annotated-doc, u
#  => => # vicorn, typing-inspection, scipy, pydantic-core, anyio, starlette, sci
#  => => # kit-learn, pydantic, fastapi
# [+] Building 5.5s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1.  5.5s
#  => => # Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#  => => # Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
#  => => # Installing collected packages: typing-extensions, threadpoolctl, sniff
#  => => # io, numpy, joblib, idna, h11, click, annotated-types, annotated-doc, u
#  => => # vicorn, typing-inspection, scipy, pydantic-core, anyio, starlette, sci
# ...
#  => => # this warning.
#  => => # [notice] A new release of pip is available: 25.1.1 -> 25.3
#  => => # [notice] To update, run: pip install --upgrade pip
# [+] Building 16.5s (6/8)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.5s
#  => => #  rendering your system unusable. It is recommended to use a virtual en
#  => => # vironment instead: https://pip.pypa.io/warnings/venv. Use the --root-u
#  => => # ser-action option if you know what you are doing and want to suppress
#  => => # this warning.
#  => => # [notice] A new release of pip is available: 25.1.1 -> 25.3
#  => => # [notice] To update, run: pip install --upgrade pip
# [+] Building 16.7s (6/8)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.6s
#  => => #  rendering your system unusable. It is recommended to use a virtual en
#  => => # vironment instead: https://pip.pypa.io/warnings/venv. Use the --root-u
#  => => # ser-action option if you know what you are doing and want to suppress
#  => => # this warning.
#  => => # [notice] A new release of pip is available: 25.1.1 -> 25.3
#  => => # [notice] To update, run: pip install --upgrade pip
# [+] Building 16.7s (7/8)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#
#
#
#
#
#
# [+] Building 16.9s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.1s
# [+] Building 17.0s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 17.2s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     0.4s
#  => => exporting layers                                                    0.4s
# [+] Building 17.3s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 17.5s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     0.7s
#  => => exporting layers                                                    0.7s
# [+] Building 17.6s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 17.8s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     1.0s
#  => => exporting layers                                                    1.0s
# [+] Building 17.9s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 18.0s (8/9)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     1.3s
#  => => exporting layers                                                    1.3s
# [+] Building 18.1s (9/9) FINISHED                                docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 575B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:2025   0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 28B                                           0.0s
#  => [1/4] FROM docker.io/agrigorev/zoomcamp-model:2025                     0.0s
#  => CACHED [2/4] WORKDIR /code                                             0.0s
#  => [3/4] RUN pip install --no-cache-dir fastapi uvicorn scikit-learn==1  16.7s
#  => [4/4] COPY app.py .                                                    0.0s
#  => exporting to image                                                     1.3s
#  => => exporting layers                                                    1.3s
#  => => writing image sha256:574c495332b0716033dfb33223920c02a6c8bd31669f3  0.0s
#  => => naming to docker.io/library/ml-zoomcamp-hw05                        0.0s
# INFO:     Started server process [1]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     172.17.0.1:38152 - "POST /predict HTTP/1.1" 200 OK
